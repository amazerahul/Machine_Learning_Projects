# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('AutoData.csv')

# %%
data.head()
# Out:
#    symboling                      make fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
data.shape
# Out:
# (205, 25)

# %%
data.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   make              205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
data.columns
# Out:
# Index(['symboling', 'make', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
listItem = []
for col in data.columns:
    listItem.append([col, data[col].dtype,
                    data[col].isnull().sum(),
                    round((data[col].isnull().sum()/len(data[col]))*100, 2),
                    data[col].nunique(),
                    list(data[col].sample(5).drop_duplicates().values)])
    
dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'], data=listItem)
dfDesc
# Out:
#         dataFeatures dataType  null  nullPct  unique  \
# 0          symboling    int64     0      0.0       6
# 1               make   object     0      0.0     147
# 2           fueltype   object     0      0.0       2
# 3         aspiration   object     0      0.0       2
# 4         doornumber   object     0      0.0       2
# 5            carbody   object     0      0.0       5
# 6         drivewheel   object     0      0.0       3
# 7     enginelocation   object     0      0.0       2
# 8          wheelbase  float64     0      0.0      53
# 9          carlength  float64     0      0.0      75
# 10          carwidth  float64     0      0.0      44
# 11         carheight  float64     0      0.0      49
# 12        curbweight    int64     0      0.0     171
# 13        enginetype   object     0      0.0       7
# 14    cylindernumber   object     0      0.0       7
# 15        enginesize    int64     0      0.0      44
# 16        fuelsystem   object     0      0.0       8
# ...

# %%
CompanyName = data['make'].apply(lambda x : x.split(' ')[0])
data.insert(3, 'CompanyName', CompanyName)
data.drop('make', axis=1, inplace=True)
data.head()
# Out:
#    symboling fueltype  CompanyName aspiration doornumber      carbody  \
# 0          3      gas  alfa-romero        std        two  convertible
# 1          3      gas  alfa-romero        std        two  convertible
# 2          1      gas  alfa-romero        std        two    hatchback
# 3          2      gas         audi        std       four        sedan
# 4          2      gas         audi        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
# 1        rwd          front       88.6      168.8  ...         130
# 2        rwd          front       94.5      171.2  ...         152
# 3        fwd          front       99.8      176.6  ...         109
# 4        4wd          front       99.4      176.6  ...         136
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# ...

# %%
data.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# There seems to be problem with the names of the CompanyName column
#
# maxda = mazda
#
# Nissan = nissan
#
# porsche = porcshce
#
# toyota = toyouta
#
# vokswagen = volkswagen = vw

# %%
# Fixing invalid values
data.CompanyName = data.CompanyName.str.lower()

def replace_carname(a, b):
    data.CompanyName.replace(a, b, inplace=True)
    
replace_carname('maxda','mazda')
replace_carname('porcshce','porsche')
replace_carname('toyouta','toyota')
replace_carname('vokswagen','volkswagen')
replace_carname('vw','volkswagen')

data.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# Check for duplicated values
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [symboling, fueltype, CompanyName, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# # Visualizing the data

# %% [markdown]
# Univariate Analysis

# %%
# Price variable distribution

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.title('Price distribution')
sns.distplot(data.price)

plt.subplot(1,2,2)
plt.title('Price spread')
data.price.plot.box()

plt.show()

# %%
data.price.describe(percentiles = [0.25, 0.50, 0.75, 0.85, 0.90, 1])
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# 85%      18500.000000
# 90%      22563.000000
# 100%     45400.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# 1. The plot seems to be right-skewed which means that most of the data points lie below 15000.
# 2. There is a significant difference between mean and median of the distribution.
# 3. The data points are spreaded far from the mean which indicates high variance.

# %%
# Categorial variables
data.select_dtypes('object')
# Out:
#     fueltype  CompanyName aspiration doornumber      carbody drivewheel  \
# 0        gas  alfa-romero        std        two  convertible        rwd
# 1        gas  alfa-romero        std        two  convertible        rwd
# 2        gas  alfa-romero        std        two    hatchback        rwd
# 3        gas         audi        std       four        sedan        fwd
# 4        gas         audi        std       four        sedan        4wd
# ..       ...          ...        ...        ...          ...        ...
# 200      gas        volvo        std       four        sedan        rwd
# 201      gas        volvo      turbo       four        sedan        rwd
# 202      gas        volvo        std       four        sedan        rwd
# 203   diesel        volvo      turbo       four        sedan        rwd
# 204      gas        volvo      turbo       four        sedan        rwd
#
#     enginelocation enginetype cylindernumber fuelsystem
# ...

# %% [markdown]
# ## Categorical variable analysis

# %%
plt.figure(figsize=(17,5))

plt.subplot(1,3,1)
plt.title('Fuel Type')
data.fueltype.value_counts().plot.bar()

plt.subplot(1,3,2)
plt.title('Company Name')
data.CompanyName.value_counts().plot.bar()

plt.subplot(1,3,3)
plt.title('Car Type')
data.carbody.value_counts().plot.bar()

plt.show()

# %% [markdown]
# 1. It seems that there are more gas fuel tank cars.
# 2. Toyata is the most favourable company.
# 3. Sedan is most preferable among car types.

# %%
categorical = data.select_dtypes('object').columns
categorical = categorical.drop(['CompanyName', 'carbody'])

# %%
categorical
# Out:
# Index(['fueltype', 'aspiration', 'doornumber', 'drivewheel', 'enginelocation',
#        'enginetype', 'cylindernumber', 'fuelsystem'],
#       dtype='object')

# %%
def plot_var(x, fig):
    plt.subplot(8,2,fig)
    plt.title(x+' Histogram')
    sns.countplot(data[x], palette='magma')
    plt.subplot(8,2,fig+1)
    plt.title(x+' vs Price')
    sns.boxplot(x=data[x], y=data.price, palette='magma')
plt.figure(figsize=(15,45))

x = 1
for col in categorical:
    plot_var(col,x)
    x = x + 2

# %% [markdown]
# ### Inferences

# %% [markdown]
# 1. Cars with diesel fuel type are higher in price as compared to gas fuel type.
# 2. Turbo aspiration has seems to have higher price that std.
# 3. The number of doors on the cars does have a significant effect on the price of the cars.
# 4. Real wheel drive has higher priority for high price cars.
# 5. The location of the engine has great impact on the price and specifically, the ones having the engine in rare part has higher prices.
# 6. The type of engine has great influence on the price like here in this case ohcv.
# 7. When the cylinder on the cars increases the the price automatically increases.
# 8. Fuel system has moderate effect on our target variable.

# %% [markdown]
# Effect on avg. price by CompanyName, CarType and FuelType

# %%
df = pd.DataFrame(data.groupby('CompanyName')['price'].mean().sort_values(ascending=False))
df.plot.bar()

df1 = pd.DataFrame(data.groupby('fueltype')['price'].mean().sort_values(ascending=False))
df1.plot.bar()

df2 = pd.DataFrame(data.groupby('carbody')['price'].mean().sort_values(ascending=False))
df2.plot.bar()

plt.show()

# %% [markdown]
# ### Inferences

# %% [markdown]
# 1. Jaguar and buick seems to have highest avg price.
# 2. Diesel has the higher avg price than gas fuel type.
# 3. In case of carbody hardtop and convertible has highest avg price.

# %% [markdown]
# # Numerical variable analysis

# %%
num_corr = data.corr()['price'].sort_values(ascending=False)
num_corr = num_corr[num_corr>0.50][1:]
num_corr
# Out:
# enginesize    0.874145
# curbweight    0.835305
# horsepower    0.808139
# carwidth      0.759325
# carlength     0.682920
# wheelbase     0.577816
# boreratio     0.553173
# Name: price, dtype: float64

# %%
def num_plot(x, fig):
    plt.subplot(4,2,fig)
    plt.scatter(x=data[x], y=data['price'])
    plt.title(x+' vs price')
    plt.ylabel('Price')
    plt.xlabel(x)
plt.figure(figsize=(12,17))
x = 1
for col in num_corr.index:
    num_plot(col,x)
    x = x + 1
plt.tight_layout()

# %% [markdown]
# All these above variables plotted against price seems to have positive correlation and can affect the price of a car significantly.

# %% [markdown]
# ## Adding new feature

# %%
data['fueleconomy'] = (0.55 * data['citympg']) + (0.45 * data['highwaympg'])

# %%
#Binning the Car Companies based on avg prices of each Company.
data['price'] = data['price'].astype('int')
temp = data.copy()
table = temp.groupby(['CompanyName'])['price'].mean()
temp = temp.merge(table.reset_index(), how='left',on='CompanyName')
bins = [0,10000,20000,40000]
data_bin=['Budget','Medium','Highend']
data['carsrange'] = pd.cut(temp['price_y'],bins,right=False,labels=data_bin)
data.head()
# Out:
#    symboling fueltype  CompanyName aspiration doornumber      carbody  \
# 0          3      gas  alfa-romero        std        two  convertible
# 1          3      gas  alfa-romero        std        two  convertible
# 2          1      gas  alfa-romero        std        two    hatchback
# 3          2      gas         audi        std       four        sedan
# 4          2      gas         audi        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  boreratio  stroke  \
# 0        rwd          front       88.6      168.8  ...       3.47    2.68
# 1        rwd          front       88.6      168.8  ...       3.47    2.68
# 2        rwd          front       94.5      171.2  ...       2.68    3.47
# 3        fwd          front       99.8      176.6  ...       3.19    3.40
# 4        4wd          front       99.4      176.6  ...       3.19    3.40
#
#    compressionratio horsepower peakrpm  citympg highwaympg  price  \
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(8,6))

plt.title('Fuel economy vs Price')
sns.scatterplot(x=data['fueleconomy'],y=data['price'],hue=data['drivewheel'])
plt.xlabel('Fuel Economy')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# Fuel economy seems to have negative correlation with the price and it is obvious.

# %%
plt.figure(figsize=(25, 6))

df = pd.DataFrame(data.groupby(['fuelsystem','drivewheel','carsrange'])['price'].mean().unstack(fill_value=0))
df.plot.bar()
plt.title('Car Range vs Average Price')
plt.show()

# %% [markdown]
# Higher ranged car seems to prefer rwd drivewheel with idi and mpfi fuel system.

# %%
g = sns.FacetGrid(data, col='doornumber', hue='carbody')
g.map(plt.scatter, 'carlength', 'price')
g.add_legend()
plt.show()

# %% [markdown]
# List of variables which influences the price of a car
# - Car Range
# - Engine Type
# - Fuel type
# - Car Body
# - Aspiration
# - Cylinder Number
# - Drivewheel
# - Curbweight
# - Car Length
# - Car width
# - Engine Size
# - Boreratio
# - Horse Power
# - Wheel base
# - Fuel Economy

# %%
data_lr = data[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                    'fueleconomy', 'carlength','carwidth', 'carsrange']]
data_lr.head()
# Out:
#    price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495      gas        std  convertible        rwd       88.6        2548
# 1  16500      gas        std  convertible        rwd       88.6        2548
# 2  16500      gas        std    hatchback        rwd       94.5        2823
# 3  13950      gas        std        sedan        fwd       99.8        2337
# 4  17450      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  fueleconomy  \
# 0       dohc           four         130       3.47         111        23.70
# 1       dohc           four         130       3.47         111        23.70
# 2       ohcv            six         152       2.68         154        22.15
# 3        ohc           four         109       3.19         102        26.70
# 4        ohc           five         136       3.19         115        19.80
#
#    carlength  carwidth carsrange
# ...

# %% [markdown]
# # Dummy Variables

# %%
def get_dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df
# Applying the function to the cars_lr

column = ['fueltype', 'aspiration', 'carbody', 'drivewheel', 'enginetype', 'cylindernumber', 'carsrange']

for col in column:
    data_lr = get_dummies(col,data_lr)

# %%
data_lr.head()
# Out:
#    price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 0  13495       88.6        2548         130       3.47         111
# 1  16500       88.6        2548         130       3.47         111
# 2  16500       94.5        2823         152       2.68         154
# 3  13950       99.8        2337         109       3.19         102
# 4  17450       99.4        2824         136       3.19         115
#
#    fueleconomy  carlength  carwidth  gas  ...  ohcv  rotor  five  four  six  \
# 0        23.70      168.8      64.1    1  ...     0      0     0     1    0
# 1        23.70      168.8      64.1    1  ...     0      0     0     1    0
# 2        22.15      171.2      65.5    1  ...     1      0     0     0    1
# 3        26.70      176.6      66.2    1  ...     0      0     0     1    0
# 4        19.80      176.6      66.4    1  ...     0      0     1     0    0
#
#    three  twelve  two  Medium  Highend
# 0      0       0    0       1        0
# ...

# %%
data_lr.shape
# Out:
# (205, 31)

# %%
from sklearn.model_selection import train_test_split

np.random.seed(0)
df_train, df_test = train_test_split(data_lr, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','fueleconomy','carlength','carwidth','price']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#         price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 90   0.055270   0.230321    0.129197    0.128906   0.077670    0.012712
# 33   0.039367   0.206997    0.096473    0.085938   0.000000    0.101695
# 45   0.105965   0.230321    0.083298    0.078125   0.116505    0.076271
# 188  0.136069   0.311953    0.249469    0.152344   0.271845    0.203390
# 203  0.484125   0.655977    0.639184    0.292969   0.097087    0.228814
#
#      fueleconomy  carlength  carwidth  gas  ...  ohcv  rotor  five  four  six  \
# 90      0.890261   0.325984  0.132653    0  ...     0      0     0     1    0
# 33      0.466392   0.085039  0.153061    1  ...     0      0     0     1    0
# 45      0.698217   0.177953  0.112245    1  ...     0      0     0     1    0
# 188     0.381344   0.426772  0.306122    1  ...     0      0     0     1    0
# 203     0.319616   0.696063  0.653061    0  ...     0      0     0     0    1
#
#      three  twelve  two  Medium  Highend
# ...

# %%
df_train.describe()
# Out:
#             price   wheelbase  curbweight  enginesize   boreratio  horsepower  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  143.000000
# mean     0.239957    0.365206    0.377450    0.230769    0.436146    0.232280
# std      0.218285    0.179782    0.222193    0.161806    0.249537    0.172143
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.086365    0.230321    0.203145    0.109375    0.252427    0.088983
# 50%      0.161263    0.309038    0.317467    0.195312    0.427184    0.182203
# 75%      0.322094    0.460641    0.536549    0.296875    0.660194    0.296610
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        fueleconomy   carlength    carwidth         gas  ...        ohcv  \
# count   143.000000  143.000000  143.000000  143.000000  ...  143.000000
# mean      0.344499    0.480877    0.370059    0.888112  ...    0.069930
# ...

# %%
y_train = df_train.pop('price')
X_train = df_train

# %% [markdown]
# # Model Building

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
rfe = RFE(lm, 10)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('wheelbase', False, 9),
#  ('curbweight', True, 1),
#  ('enginesize', True, 1),
#  ('boreratio', False, 12),
#  ('horsepower', True, 1),
#  ('fueleconomy', True, 1),
#  ('carlength', False, 11),
#  ('carwidth', True, 1),
#  ('gas', False, 20),
#  ('turbo', False, 19),
#  ('hardtop', False, 10),
#  ('hatchback', False, 6),
#  ('sedan', False, 8),
#  ('wagon', False, 7),
#  ('fwd', False, 17),
#  ('rwd', False, 18),
#  ('dohcv', True, 1),
#  ('l', False, 14),
#  ('ohc', False, 15),
#  ('ohcf', False, 13),
#  ('ohcv', False, 5),
#  ('rotor', False, 4),
#  ('five', True, 1),
#  ('four', True, 1),
#  ('six', False, 3),
#  ('three', False, 21),
#  ('twelve', True, 1),
#  ('two', False, 2),
#  ('Medium', False, 16),
#  ('Highend', True, 1)]

# %%
X_train.columns[rfe.support_]
# Out:
# Index(['curbweight', 'enginesize', 'horsepower', 'fueleconomy', 'carwidth',
#        'dohcv', 'five', 'four', 'twelve', 'Highend'],
#       dtype='object')

# %%
X_train_rfe = X_train[X_train.columns[rfe.support_]]
X_train_rfe.head()
# Out:
#      curbweight  enginesize  horsepower  fueleconomy  carwidth  dohcv  five  \
# 90     0.129197    0.128906    0.012712     0.890261  0.132653      0     0
# 33     0.096473    0.085938    0.101695     0.466392  0.153061      0     0
# 45     0.083298    0.078125    0.076271     0.698217  0.112245      0     0
# 188    0.249469    0.152344    0.203390     0.381344  0.306122      0     0
# 203    0.639184    0.292969    0.228814     0.319616  0.653061      0     0
#
#      four  twelve  Highend
# 90      1       0        0
# 33      1       0        0
# 45      1       0        0
# 188     1       0        0
# 203     0       0        0

# %%
def build_model(X,y):
    X = sm.add_constant(X) #Adding the constant
    lm = sm.OLS(y,X).fit() # fitting the model
    print(lm.summary()) # model summary
    return X
    
def checkVIF(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %%
X_train_new = build_model(X_train_rfe,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     186.1
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           1.08e-72
# Time:                        18:37:27   Log-Likelihood:                 209.34
# No. Observations:                 143   AIC:                            -396.7
# Df Residuals:                     132   BIC:                            -364.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0392      0.040     -0.978      0.330      -0.118       0.040
# ...

# %%
X_train_new = X_train_rfe.drop(['five'], axis=1)

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     204.9
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           2.03e-73
# Time:                        18:37:28   Log-Likelihood:                 208.22
# No. Observations:                 143   AIC:                            -396.4
# Df Residuals:                     133   BIC:                            -366.8
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0525      0.039     -1.342      0.182      -0.130       0.025
# ...

# %%
X_train_new = X_train_new.drop(['twelve','enginesize'],axis=1)

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     258.0
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           7.20e-75
# Time:                        18:37:28   Log-Likelihood:                 205.83
# No. Observations:                 143   AIC:                            -395.7
# Df Residuals:                     135   BIC:                            -372.0
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0285      0.038     -0.758      0.450      -0.103       0.046
# ...

# %%
X_train_new = X_train_new.drop(['fueleconomy'],axis=1)

# %%
build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     297.5
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           1.32e-75
# Time:                        18:37:28   Log-Likelihood:                 204.57
# No. Observations:                 143   AIC:                            -395.1
# Df Residuals:                     136   BIC:                            -374.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0179      0.023      0.780      0.437      -0.027       0.063
# ...

# %%
checkVIF(X_train_new)
# Out:
#      Features    VIF
# 0       const  21.30
# 1  curbweight   5.79
# 3    carwidth   4.46
# 2  horsepower   2.90
# 5        four   2.08
# 6     Highend   1.67
# 4       dohcv   1.37

# %%
build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     297.5
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           1.32e-75
# Time:                        18:37:28   Log-Likelihood:                 204.57
# No. Observations:                 143   AIC:                            -395.1
# Df Residuals:                     136   BIC:                            -374.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0179      0.023      0.780      0.437      -0.027       0.063
# ...

# %%
checkVIF(X_train_new)
# Out:
#      Features    VIF
# 0       const  21.30
# 1  curbweight   5.79
# 3    carwidth   4.46
# 2  horsepower   2.90
# 5        four   2.08
# 6     Highend   1.67
# 4       dohcv   1.37

# %%
X_train_new = X_train_new.drop(['curbweight'],1)
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     335.2
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           5.71e-75
# Time:                        18:37:28   Log-Likelihood:                 199.90
# No. Observations:                 143   AIC:                            -387.8
# Df Residuals:                     137   BIC:                            -370.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0183      0.024      0.777      0.439      -0.028       0.065
# ...

# %%
checkVIF(X_train_new)
# Out:
#      Features    VIF
# 0       const  21.30
# 1  horsepower   2.21
# 4        four   2.07
# 2    carwidth   1.73
# 5     Highend   1.64
# 3       dohcv   1.19

# %% [markdown]
# ## Residual Analysis of Model

# %%
lm = sm.OLS(y_train,X_train_new).fit()
y_train_price = lm.predict(X_train_new)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# ## Prediction and Evaluation

# %%
#Scaling the test set
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','fueleconomy','carlength','carwidth','price']
df_test[num_vars] = scaler.fit_transform(df_test[num_vars])

# %%
#Dividing into X and y
y_test = df_test.pop('price')
X_test = df_test

# %%
# Now let's use our model to make predictions.
X_train_new = X_train_new.drop('const',axis=1)
# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[X_train_new.columns]

# Adding a constant variable 
X_test_new = sm.add_constant(X_test_new)

# %%
# Making predictions
y_pred = lm.predict(X_test_new)

# %%
#EVALUATION OF THE MODEL
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     335.2
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           5.71e-75
# Time:                        18:50:24   Log-Likelihood:                 199.90
# No. Observations:                 143   AIC:                            -387.8
# Df Residuals:                     137   BIC:                            -370.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0183      0.024      0.777      0.439      -0.028       0.065
# ...

# %% [markdown]
# Inferences:
# 1. p-values for all the coefficients seem to be less than 0.05 significant level. It means that all the predictors are statistically significant.
# 2. R-squared and Adjusted R-squared (extent of fit) - 0.924 and 0.922 - 92% variance explained.
# 3. F-stats and Prob(F-stats) (overall model fit) - 335.2 and 5.71e-75 - Model fir is significant and explained 92% variance is just not by chance.
